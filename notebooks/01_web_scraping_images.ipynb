# %%
from duckduckgo_search import DDGS
import requests, os
from PIL import Image
from io import BytesIO

os.makedirs("cricket_gound_images", exist_ok=True)

query = "cricket ground grass"
count = 200  # how many you want

with DDGS() as ddgs:
    results = ddgs.images(query, max_results=count)
    for i, r in enumerate(results, start=1):
        img_url = r["image"]
        try:
            img_data = requests.get(img_url, timeout=10).content
            img = Image.open(BytesIO(img_data)).convert("RGB")
            img = img.resize((800, 600))
            img.save(f"cricket_gound_images/ground_{i}.jpg")
            print(f"✅ Saved image {i}")
        except Exception as e:
            print(f"⚠️ Skipped {i}: {e}")

print("🎯 All done! Images saved in cricket_gound_images/")
# Out:
# C:\Users\swapn\AppData\Local\Temp\ipykernel_2884\2737003328.py:11: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# ---------------------------------------------------------------------------
# RatelimitException                        Traceback (most recent call last)
# Cell In[2], line 12
#       9 count = 200  # how many you want
#      11 with DDGS() as ddgs:
# ---> 12     results = ddgs.images(query, max_results=count)
#      13     for i, r in enumerate(results, start=1):
#      14         img_url = r["image"]
#
# File c:\Users\swapn\anaconda3\Lib\site-packages\duckduckgo_search\duckduckgo_search.py:502, in DDGS.images(self, keywords, region, safesearch, timelimit, size, color, type_image, layout, license_image, max_results)
#     499 results: list[dict[str, str]] = []
#     501 for _ in range(5):
# --> 502     resp_content = self._get_url(
# ...

# %%
# %pip uninstall duckduckgo-search
