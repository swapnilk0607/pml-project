# %%
import os
import time
import requests
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from io import BytesIO
from PIL import Image
# from webdriver_manager.chrome import ChromeDriverManager

# ====== CONFIG ======
url = "https://www.espncricinfo.com/photo"  # <-- Change to your target website
download_folder = "downloaded_images"
scroll_pause_time = 2  # seconds between scrolls
max_scrolls = 10       # how many times to scroll
target_width = 800
target_height = 600
# =====================

# Setup Chrome
driver = webdriver.Chrome()

# Open the website
driver.get(url)

# Make sure folder exists
os.makedirs(download_folder, exist_ok=True)

# Scrolling and collecting image URLs
image_urls = set()
last_height = driver.execute_script("return document.body.scrollHeight")

for i in range(max_scrolls):
    print(f"Scrolling {i+1}/{max_scrolls}...")
    
    # Scroll to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    # Wait for new content to load
    time.sleep(scroll_pause_time)
    
    # Collect image elements
    # if i > 30:
    imgs = driver.find_elements(By.TAG_NAME, "img")
    for img in imgs:
        src = img.get_attribute("src")
        if src and src.startswith("http"):
            image_urls.add(src)
    
    # Check if page height stopped changing (end of page)
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

print(f"Found {len(image_urls)} images. Starting download...")
count = 100

urls_filepath = os.path.join(download_folder, "image_urls.txt")
# Download images
with open(urls_filepath, "w", encoding="utf-8") as f:
    for i, url in enumerate(image_urls):
        try:
            response = requests.get(url, timeout=10)
            img = Image.open(BytesIO(response.content))
            # Resize to 800x600
            resized = img.resize((target_width, target_height), Image.LANCZOS)
            if resized.size == (target_width, target_height):
                count += 1
                f.write(f"image_{count}.jpg # {url}\n")
                save_path = os.path.join(download_folder, f"image_{count}.jpg")
                resized.save(save_path)
                print(f"Saved image {count} ({resized.size}) from {url}")
            else:
                # Uncomment next line to print all sizes found
                print(f"Skipped ({resized.size}) {url}")
                pass

        except Exception as e:
            print(f"Error downloading {url}: {e}")

driver.quit()
print("✅ Done.")
# Out:
# Scrolling 1/10...
# Scrolling 2/10...
# Scrolling 3/10...
# Scrolling 4/10...
# Scrolling 5/10...
# Scrolling 6/10...
# Scrolling 7/10...
# Scrolling 8/10...
# Scrolling 9/10...
# Scrolling 10/10...
# Found 86 images. Starting download...
# Saved image 101 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410163.jpg
# Saved image 102 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410198.jpg
# Saved image 103 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410201.jpg
# Saved image 104 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410189.jpg
# Saved image 105 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410217.jpg
# Saved image 106 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410219.jpg
# Error downloading https://wassets.hscicdn.com/static/images/lazyimage-transparent.png: cannot write mode RGBA as JPEG
# Saved image 108 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410220.jpg
# Saved image 109 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410229.jpg
# Saved image 110 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410196.jpg
# Error downloading https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_160,q_50/lsci/db/PICTURES/CMS/381800/381894.png: cannot write mode P as JPEG
# Saved image 112 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410150.jpg
# Error downloading https://wassets.hscicdn.com/static/images/logo.png: cannot write mode P as JPEG
# Saved image 114 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410206.jpg
# Saved image 115 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410143.jpg
# Saved image 116 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410182.jpg
# Saved image 117 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410171.jpg
# Saved image 118 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410204.jpg
# Saved image 119 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410194.jpg
# Saved image 120 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410159.jpg
# Saved image 121 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410225.jpg
# Saved image 122 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410179.jpg
# Saved image 123 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410170.jpg
# Saved image 124 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410161.jpg
# Saved image 125 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410222.jpg
# Saved image 126 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410175.jpg
# Saved image 127 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410162.jpg
# Saved image 128 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410203.jpg
# Saved image 129 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410192.jpg
# Saved image 130 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410165.jpg
# Saved image 131 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_160,q_50/lsci/db/PICTURES/CMS/349600/349619.jpg
# Saved image 132 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410157.jpg
# Saved image 133 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410140.jpg
# Saved image 134 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410209.jpg
# Error downloading https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_160,q_50/lsci/db/PICTURES/CMS/382700/382733.png: cannot write mode RGBA as JPEG
# Saved image 136 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410205.jpg
# Saved image 137 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410185.jpg
# Saved image 138 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410216.jpg
# Saved image 139 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410191.jpg
# Saved image 140 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_160,q_50/lsci/db/PICTURES/CMS/327900/327910.jpg
# Saved image 141 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410199.jpg
# Saved image 142 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410148.jpg
# Saved image 143 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410164.jpg
# Saved image 144 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410147.jpg
# Error downloading https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_160,q_50/lsci/db/PICTURES/CMS/340400/340493.png: cannot write mode RGBA as JPEG
# Saved image 146 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410240.jpg
# Saved image 147 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410212.jpg
# Saved image 148 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410160.jpg
# Saved image 149 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410183.jpg
# Saved image 150 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410155.jpg
# Saved image 151 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410207.jpg
# Saved image 152 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410173.jpg
# Saved image 153 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410137.jpg
# Saved image 154 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410153.jpg
# Saved image 155 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410178.png
# Saved image 156 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_160,q_50/lsci/db/PICTURES/CMS/349600/349621.jpg
# Saved image 157 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410152.jpg
# Saved image 158 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410176.jpg
# Saved image 159 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410195.jpg
# Saved image 160 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410230.jpg
# Saved image 161 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410172.jpg
# Saved image 162 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410210.jpg
# Saved image 163 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410166.jpg
# Saved image 164 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410226.jpg
# Error downloading https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_160,q_50/lsci/db/PICTURES/CMS/381800/381895.png: cannot write mode RGBA as JPEG
# Saved image 166 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_wide_w_1200,q_60/lsci/db/PICTURES/CMS/410200/410243.jpg
# Saved image 167 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410241.jpg
# Saved image 168 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410200.jpg
# Saved image 169 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410184.jpg
# Saved image 170 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410181.jpg
# Saved image 171 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410202.jpg
# Saved image 172 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410167.jpg
# Saved image 173 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410168.jpg
# Saved image 174 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410180.jpg
# Saved image 175 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410149.jpg
# Error downloading https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg: cannot identify image file <_io.BytesIO object at 0x0000024CCAAB6430>
# Saved image 176 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410177.jpg
# Saved image 177 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410193.jpg
# Saved image 178 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410239.jpg
# Saved image 179 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410169.jpg
# Error downloading https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_160,q_50/lsci/db/PICTURES/CMS/313300/313321.logo.png: cannot write mode RGBA as JPEG
# Saved image 181 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410200/410223.jpg
# Saved image 182 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410139.jpg
# Saved image 183 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410138.jpg
# Saved image 184 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410190.jpg
# Saved image 185 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/410100/410154.jpg
# ✅ Done.
