# %%
import os
import time
import requests
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from io import BytesIO
from PIL import Image
# from webdriver_manager.chrome import ChromeDriverManager

# ====== CONFIG ======
url = "https://www.espncricinfo.com/photo"  # <-- Change to your target website
download_folder = "downloaded_images"
scroll_pause_time = 2  # seconds between scrolls
max_scrolls = 10       # how many times to scroll
target_width = 800
target_height = 600
# =====================

# Setup Chrome
driver = webdriver.Chrome()

# Open the website
driver.get(url)

# Make sure folder exists
os.makedirs(download_folder, exist_ok=True)

# Scrolling and collecting image URLs
image_urls = set()
last_height = driver.execute_script("return document.body.scrollHeight")

for i in range(max_scrolls):
    print(f"Scrolling {i+1}/{max_scrolls}...")
    
    # Scroll to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    # Wait for new content to load
    time.sleep(scroll_pause_time)
    
    # Collect image elements
    imgs = driver.find_elements(By.TAG_NAME, "img")
    for img in imgs:
        src = img.get_attribute("src")
        if src and src.startswith("http"):
            image_urls.add(src)
    
    # Check if page height stopped changing (end of page)
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

print(f"Found {len(image_urls)} images. Starting download...")
count = 0
# Download images
for i, url in enumerate(image_urls):
    # try:
    #     img_data = requests.get(url, timeout=10).content
    #     img_data
    #     with open(os.path.join(download_folder, f"image_{i+1}.jpg"), "wb") as f:
    #         f.write(img_data)
    #     print(f"Downloaded {i+1}/{len(image_urls)}")
    # except Exception as e:
    #     print(f"Failed to download {url}: {e}")
    try:
        response = requests.get(url, timeout=10)
        img = Image.open(BytesIO(response.content))
        # Resize to 800x600
        resized = img.resize((target_width, target_height), Image.LANCZOS)
        if resized.size == (target_width, target_height):
            count += 1
            save_path = os.path.join(download_folder, f"image_{count}.jpg")
            resized.save(save_path)
            print(f"Saved image {count} ({resized.size}) from {url}")
        else:
            # Uncomment next line to print all sizes found
            print(f"Skipped ({resized.size}) {url}")
            pass

    except Exception as e:
        print(f"Error downloading {url}: {e}")

driver.quit()
print("✅ Done.")
# Out:
# Scrolling 1/10...
# Scrolling 2/10...
# Scrolling 3/10...
# Scrolling 4/10...
# Scrolling 5/10...
# Scrolling 6/10...
# Scrolling 7/10...
# Scrolling 8/10...
# Scrolling 9/10...
# Scrolling 10/10...
# Found 73 images. Starting download...
# Saved image 1 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_wide_w_1200,q_60/lsci/db/PICTURES/CMS/409100/409143.jpg
# Saved image 2 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409103.jpg
# Saved image 3 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409112.jpg
# Saved image 4 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409074.jpg
# Error downloading https://wassets.hscicdn.com/static/images/lazyimage-transparent.png: cannot write mode RGBA as JPEG
# Saved image 6 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409124.jpg
# Saved image 7 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409141.jpg
# Saved image 8 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409118.png
# Saved image 9 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409050.jpg
# Saved image 10 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409036.jpg
# Saved image 11 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409028.jpg
# Saved image 12 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409107.jpg
# Saved image 13 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409117.png
# Saved image 14 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409130.jpg
# Saved image 15 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409102.jpg
# Saved image 16 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409092.jpg
# Saved image 17 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409093.jpg
# Error downloading https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409090.png: cannot write mode RGBA as JPEG
# Error downloading https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_160,q_50/lsci/db/PICTURES/CMS/313500/313505.logo.png: cannot write mode RGBA as JPEG
# Error downloading https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_160,q_50/lsci/db/PICTURES/CMS/340000/340047.png: cannot write mode RGBA as JPEG
# Saved image 21 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_160,q_50/lsci/db/PICTURES/CMS/317300/317354.jpg
# Saved image 22 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409053.jpg
# Saved image 23 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409106.png
# Saved image 24 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409109.jpg
# Saved image 25 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409078.jpg
# Saved image 26 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409114.jpg
# Saved image 27 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409057.jpg
# Error downloading https://wassets.hscicdn.com/static/images/logo.png: cannot write mode P as JPEG
# Saved image 29 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409096.jpg
# Saved image 30 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409098.jpg
# Saved image 31 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409042.jpg
# Saved image 32 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409044.jpg
# Saved image 33 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409077.jpg
# Saved image 34 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409123.jpg
# Saved image 35 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409071.jpg
# Saved image 36 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409032.jpg
# Saved image 37 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409116.jpg
# Saved image 38 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409063.jpg
# Saved image 39 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409115.jpg
# Saved image 40 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409066.jpg
# Saved image 41 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409104.png
# Saved image 42 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409056.jpg
# Saved image 43 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409062.jpg
# Saved image 44 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409046.jpg
# Saved image 45 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409080.jpg
# Saved image 46 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409137.jpg
# Saved image 47 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409121.jpg
# Saved image 48 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409075.jpg
# Saved image 49 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409127.jpg
# Saved image 50 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409105.png
# Saved image 51 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409088.png
# Saved image 52 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409142.jpg
# Saved image 53 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409072.jpg
# Saved image 54 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409120.jpg
# Saved image 55 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409051.jpg
# Error downloading https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_160,q_50/lsci/db/PICTURES/CMS/341400/341456.png: cannot write mode P as JPEG
# Error downloading https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_160,q_50/lsci/db/PICTURES/CMS/313100/313149.logo.png: cannot write mode RGBA as JPEG
# Error downloading https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_160,q_50/lsci/db/PICTURES/CMS/313500/313508.logo.png: cannot write mode RGBA as JPEG
# Saved image 59 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409094.jpg
# Saved image 60 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409086.jpg
# Saved image 61 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409140.jpg
# Error downloading https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_160,q_50/lsci/db/PICTURES/CMS/381800/381891.png: cannot write mode RGBA as JPEG
# Error downloading https://img1.hscicdn.com/image/upload/f_auto,t_ds_square_w_160,q_50/lsci/db/PICTURES/CMS/327900/327931.png: cannot write mode RGBA as JPEG
# Error downloading https://wassets.hscicdn.com/static/images/lazyimage-noaspect.svg: cannot identify image file <_io.BytesIO object at 0x0000023B11972160>
# Saved image 64 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409060.jpg
# Saved image 65 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409059.jpg
# Saved image 66 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409081.png
# Saved image 67 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409083.jpg
# Saved image 68 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409084.jpg
# Saved image 69 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409054.jpg
# Saved image 70 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409022.jpg
# Saved image 71 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409100/409126.jpg
# Saved image 72 ((800, 600)) from https://img1.hscicdn.com/image/upload/f_auto,t_ds_w_960,q_50/lsci/db/PICTURES/CMS/409000/409091.jpg
# ✅ Done.
